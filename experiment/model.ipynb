# %% [markdown]
# # DOWNLOADING DATASET USING KAGGLE API KEY

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mirichoi0218/insurance")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\LENOVO\.cache\kagglehub\datasets\mirichoi0218\insurance\versions\1

# %% [markdown]
# # READING DATASET USING PANDAS

# %%
import pandas as pd

# Load the dataset using pandas
df = pd.read_csv(path + "/insurance.csv")  # Adjust the file name if it's different

# %% [markdown]
# ## UNDERSTANDING DATA PROPERLY

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
# CHECKING THE SHAPE AND SIZE OF THE DATASET

print("Shape of the dataset :",df.shape)
# Out:
# Shape of the dataset : (1338, 7)

# %%
df.sample()
# Out:
#      age   sex    bmi  children smoker     region    charges
# 881   23  male  27.36         1     no  northwest  2789.0574

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#  CHECKING THE MISSING VALUES

df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
#  CHECKING ALL THE MISSING VALUES

df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# CHECKING DATA USING MATHEMATICALLY

df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# CHECKING DUPLICATE VALUES

df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
# CHECKING THE SUM OF DUPLICATE VALUES

df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# ## PERFORMING EXPLORATORY DATA ANALYSIS

# %%
import seaborn as sns

# %%
df.sample(5)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 180    58    male  28.595         0     no  northwest  11735.87905
# 1113   28  female  26.315         3     no  northwest   5312.16985
# 447    56  female  25.650         0     no  northwest  11454.02150
# 1070   37    male  37.070         1    yes  southeast  39871.70430
# 544    54    male  30.210         0     no  northwest  10231.49990

# %% [markdown]
# # EDA WITH UNIVARIATE VISUALIZATION ANALYSIS

# %% [markdown]
# ## ANALYSIS WITH THE CATEGORICAL ANALYSIS

# %%
sns.countplot(df["sex"])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %% [markdown]
# NUMBER OF MAN ARE EQUAL TO NUMBER OF WOMAN

# %%
df["smoker"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## ANALYSIS WITH THE NUMERICAL ANALYSIS

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["age"])
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(df["age"])

# %%
sns.boxplot(df["bmi"])
# Out:
# <Axes: ylabel='bmi'>

# %%
sns.boxplot(df["age"])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(df["children"])
# Out:
# <Axes: ylabel='children'>

# %%
sns.boxplot(df["charges"]) # CHECKING THE TARGET VARIABLE
# Out:
# <Axes: ylabel='charges'>

# %% [markdown]
# INDIVUAL ANALYSIS OF THE FEATURES OF ARE DONE AND UNDERSTOOD

# %% [markdown]
# ## EDA USING BIVARIATE AND MULTI-VARIATE ANALYSIS

# %%
df.sample()
# Out:
#      age   sex     bmi  children smoker     region     charges
# 546   28  male  35.435         0     no  northeast  3268.84665

# %%
sns.scatterplot((df["age"],df["bmi"]))
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x="bmi", y="charges", data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x="sex", y="charges", data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create a contingency table
table = pd.crosstab(df["sex"], df["smoker"])

# Plot heatmap
sns.heatmap(table, annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
#  ABOVE ALL THE VISUALISATIONS HAS BEEN DONE PROPERLY USING ALL THE RELEVANT PLOTS

# %% [markdown]
# ## EDA CAN ALSO BE PERFORMED USING PANDAS-PROFILING IN JUST 3 LINES OF CODE

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\LENOVO\anaconda3\envs\cost\python.exe

# %% [markdown]
# # FEATURE ENGINEERING
